# %%
import numpy as np
import pandas as pd

# this function just chooses random index positions to delete later
def binary_sampler(p, rows, cols): # got this code from: https://github.com/jsyoon0823/GAIN/blob/master/utils.py
  '''Sample binary random variables.

  Args:
    - p: probability of 1
    - rows: the number of rows
    - cols: the number of columns

  Returns:
    - binary_random_matrix: generated binary random matrix.
  '''
  np.random.seed(77)
  unif_random_matrix = np.random.uniform(0., 1., size = [rows, cols])
  binary_random_matrix = 1*(unif_random_matrix < p)
  return binary_random_matrix

# %%
data = pd.read_csv('T_no_missing.csv')
countries = data["Country"]
data = data.drop(columns=["Country"]) # need to include this only so it doesn't drop the countries

# Parameters
no, dim = data.shape

miss_rate = 0.05 # what percent of data to remove -- similar to as in the original data

# Make missing data
data_m = binary_sampler(1-miss_rate, no, dim) # choose what index positions to delete
T_missing = data.copy()
T_missing[data_m == 0] = np.nan # delete the index positions

# add back in the country column and put it as the frst column
T_missing["Country"] = countries
cols = T_missing.columns.tolist()
cols = cols[-1:] + cols[:-1]
T_missing = T_missing[cols]

print(T_missing) # this is the dataset with some deleted
# Out:
#                           Country  T1992  T1993  T1994  T1995  T1996  T1997  \
# 0    Afghanistan, Islamic Rep. of -0.294  0.220  0.430  0.359 -0.116  0.471
# 1                         Albania  0.106  0.076  1.330 -0.172 -0.038  0.075
# 2                         Algeria -0.312  0.552  0.732  0.595  0.846  1.059
# 3        Andorra, Principality of  0.386  0.174  1.508  1.279  0.570  1.788
# 4                          Angola  0.466  0.256  0.212  0.753  0.370  0.107
# ..                            ...    ...    ...    ...    ...    ...    ...
# 179            West Bank and Gaza -1.045 -0.368  0.800 -0.166  0.338 -0.121
# 180                Western Sahara  0.529  0.315  0.903  1.356  1.353  1.536
# 181                         World  0.184  0.348  0.507  0.835    NaN  0.656
# 182                        Zambia  0.544 -0.117  0.362  0.761  0.393  0.339
# 183                      Zimbabwe  1.010  0.300 -0.085  0.685 -0.247 -0.025
#
#      T1998  T1999  T2000  ...  T2011  T2012  T2013  T2014  T2015  T2016  \
# 0    0.675  1.198  0.993  ...  1.397  0.223  1.281  0.456  1.093  1.555
# 1    0.795  0.670  1.065  ...  1.055  1.487  1.333  1.198  1.569  1.464
# 2    1.109  1.476    NaN  ...  1.398  1.147  1.192  1.690  1.121  1.757
# 3    1.018  1.055  1.050  ...  1.677  1.265  0.831  1.946  1.690  1.990
# 4    1.064  0.417  0.169  ...  0.880  0.552  1.044  0.828  1.331  1.609
# ..     ...    ...    ...  ...    ...    ...    ...    ...    ...    ...
# 179  0.894  0.900  0.249  ...  0.581  1.043  1.114  0.863  1.326  1.615
# 180  1.415  0.935  0.874  ...  1.579  1.344  1.423  1.401  1.510  1.732
# 181  0.993  0.783  0.728  ...  0.921  1.074  1.016  1.053  1.412  1.660
# 182  0.876  0.064 -0.040  ...  0.956  0.972  0.790  0.917  1.450  1.401
# 183  0.801  0.030 -0.417  ...  0.232  0.334  0.118  0.025  0.970  1.270
#
#      T2017  T2018  T2019  T2020
# 0    1.540  1.544  0.910  0.498
# 1    1.121  2.028  1.675  1.498
# 2    1.512  1.210  1.115  1.926
# 3    1.925  1.919  1.964  2.562
# 4    0.870  1.395  1.752    NaN
# ..     ...    ...    ...    ...
# 179  0.735  2.007  1.204  1.455
# 180  2.204  0.942  1.477  2.069
# 181  1.429  1.290  1.444  1.711
# 182  0.105  0.648  0.855  0.891
# 183  0.088  0.453  0.925  0.389
#
# [184 rows x 30 columns]

# %%
from google.colab import files

T_missing.to_csv('T_missing.csv',index=False)
files.download('T_missing.csv')
