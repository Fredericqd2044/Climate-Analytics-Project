# %%
import pandas as pd
import numpy as np

from google.colab import drive
from google.colab import files
drive.mount('/content/drive')

T_data_filepath = '/content/drive/MyDrive/Spring 2024/Advanced Topics in Data Science/MLCC Project/data/T_preprocessed.csv'
T_preproc_data = pd.read_csv(T_data_filepath)
# Out:
# Mounted at /content/drive

# %%
null_rows = T_preproc_data.isnull().any(axis=1)

# Display rows with at least one null value
T_preproc_data[null_rows] # 41 rows with missing values
# Out:
#                                  Country  T1992  T1993  T1994  T1995  T1996  \
# 3                         American Samoa  0.344 -0.069  0.189  0.755  0.784
# 7                    Antigua and Barbuda  0.445  0.528  0.493  0.677  0.377
# 10     Aruba, Kingdom of the Netherlands    NaN    NaN  0.528  0.802    NaN
# 17                              Barbados  0.333  0.394  0.388  0.463  0.315
# 19                               Belgium    NaN    NaN    NaN    NaN    NaN
# 31                               Burundi  0.004    NaN    NaN    NaN    NaN
# 32                            Cabo Verde  0.888  0.508  0.442  1.475  1.598
# 36                        Cayman Islands  0.549  1.055  1.326  1.355  0.780
# 46                        Congo, Rep. of -0.314  0.007  0.223  0.426 -0.058
# 48                            Costa Rica  0.498  0.308  0.514  0.633 -0.021
# 52                            Czech Rep.    NaN  0.293  1.807  1.044 -0.602
# ...

# %%
T_no_missing = T_preproc_data.dropna(axis=0)
T_no_missing
# Out:
#                           Country  T1992  T1993  T1994  T1995  T1996  T1997  \
# 0    Afghanistan, Islamic Rep. of -0.294  0.220  0.430  0.359 -0.116  0.471
# 1                         Albania  0.106  0.076  1.330 -0.172 -0.038  0.075
# 2                         Algeria -0.312  0.552  0.732  0.595  0.846  1.059
# 4        Andorra, Principality of  0.386  0.174  1.508  1.279  0.570  1.788
# 5                          Angola  0.466  0.256  0.212  0.753  0.370  0.107
# ..                            ...    ...    ...    ...    ...    ...    ...
# 219            West Bank and Gaza -1.045 -0.368  0.800 -0.166  0.338 -0.121
# 220                Western Sahara  0.529  0.315  0.903  1.356  1.353  1.536
# 221                         World  0.184  0.348  0.507  0.835  0.355  0.656
# 223                        Zambia  0.544 -0.117  0.362  0.761  0.393  0.339
# 224                      Zimbabwe  1.010  0.300 -0.085  0.685 -0.247 -0.025
#
# ...

# %%
T_no_missing.to_csv('T_no_missing.csv',index=False)
files.download('T_no_missing.csv')
