# %%
# import methods
import pandas as pd

# %%
# original data
T = pd.read_csv('Annual_Surface_Temperature_Change.csv')
T
# Out:
#      ObjectId                       Country ISO2 ISO3  \
# 0           1  Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                       Albania   AL  ALB
# 2           3                       Algeria   DZ  DZA
# 3           4                American Samoa   AS  ASM
# 4           5      Andorra, Principality of   AD  AND
# ..        ...                           ...  ...  ...
# 220       221                Western Sahara   EH  ESH
# 221       222                         World  NaN  WLD
# 222       223                Yemen, Rep. of   YE  YEM
# 223       224                        Zambia   ZM  ZMB
# 224       225                      Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 0    Temperature change with respect to a baseline ...  Degree Celsius
# 1    Temperature change with respect to a baseline ...  Degree Celsius
# 2    Temperature change with respect to a baseline ...  Degree Celsius
# ...

# %%
# Keep Country and Years 1992-2020 columns
selected_columns = ['Country'] + [f'F{year}' for year in range(1992, 2021)]
T_selected = T[selected_columns]
T_selected
# Out:
#                           Country  F1992  F1993  F1994  F1995  F1996  F1997  \
# 0    Afghanistan, Islamic Rep. of -0.294  0.220  0.430  0.359 -0.116  0.471
# 1                         Albania  0.106  0.076  1.330 -0.172 -0.038  0.075
# 2                         Algeria -0.312  0.552  0.732  0.595  0.846  1.059
# 3                  American Samoa  0.344 -0.069  0.189  0.755  0.784    NaN
# 4        Andorra, Principality of  0.386  0.174  1.508  1.279  0.570  1.788
# ..                            ...    ...    ...    ...    ...    ...    ...
# 220                Western Sahara  0.529  0.315  0.903  1.356  1.353  1.536
# 221                         World  0.184  0.348  0.507  0.835  0.355  0.656
# 222                Yemen, Rep. of    NaN    NaN    NaN    NaN    NaN  0.107
# 223                        Zambia  0.544 -0.117  0.362  0.761  0.393  0.339
# 224                      Zimbabwe  1.010  0.300 -0.085  0.685 -0.247 -0.025
#
# ...

# %%
# Rename years columns to T[Year]
renamed_columns = {'Country': 'Country'}
for year in range(1992, 2021):
    renamed_columns[f'F{year}'] = f'T{year}'

T_selected = T_selected.rename(columns=renamed_columns)
T_selected
# Out:
#                           Country  T1992  T1993  T1994  T1995  T1996  T1997  \
# 0    Afghanistan, Islamic Rep. of -0.294  0.220  0.430  0.359 -0.116  0.471
# 1                         Albania  0.106  0.076  1.330 -0.172 -0.038  0.075
# 2                         Algeria -0.312  0.552  0.732  0.595  0.846  1.059
# 3                  American Samoa  0.344 -0.069  0.189  0.755  0.784    NaN
# 4        Andorra, Principality of  0.386  0.174  1.508  1.279  0.570  1.788
# ..                            ...    ...    ...    ...    ...    ...    ...
# 220                Western Sahara  0.529  0.315  0.903  1.356  1.353  1.536
# 221                         World  0.184  0.348  0.507  0.835  0.355  0.656
# 222                Yemen, Rep. of    NaN    NaN    NaN    NaN    NaN  0.107
# 223                        Zambia  0.544 -0.117  0.362  0.761  0.393  0.339
# 224                      Zimbabwe  1.010  0.300 -0.085  0.685 -0.247 -0.025
#
# ...

# %%
# extract to csv file
file_path = "T_preprocessed.csv"
T_selected.to_csv(file_path, index=False)
print(f"T_selected has been saved to {file_path}")
# Out:
# T_selected has been saved to T_preprocessed.csv
